# %% [markdown]
# #**Funciones pt2**
#
#
# ```
# def namefunction(argument):
#   #block of code
#   #final block of code
#   retun somethings
# ```

# %% [markdown]
# #**modulo random**

# %%
import random
print(random.randint(1,6))
# Out:
# 5

# %%
def tira_dados(n_dados):
  for dado in range(n_dados):
    print(random.randint(1,6))

tira_dados(6)
# Out:
# 2
# 5
# 4
# 4
# 4
# 4

# %% [markdown]
# #**Diccionarios**
#
#
#
# *   Listas y tuplas
# *   Diccionarios y conjuntos
# *   Otros
#
#
# ```
# my_list = [1.0, 2.0, 3.0]
# my_tuple = (1.0, 2.0, 3.0)
# my_dict = {
#   "day": 6
#   "month": "August"
# }
# ```
# *   Los diccionarios funcionan con llaves, en lugar de indices
# *   existen funciones para extraer rodos los elementos de golpe

# %%
taquerias = [
    "Takesabroso",     # 0
    "El Inge",         # 1
    "Valoz",           # 2
    "Takos El buho",   # 3
    "Tacos Los Papis", # 4
    "El Taco Loco"     # 5
]
taquerias[3]
# Out:
# 'Takos El buho'

# %%
cita = [
    {
    'fecha': '04/03/21',
    'paciente': 'Carlos Ahumada',
    'medico': 'Aaron Juarez',
    'consultario': 35
    },
    {
    'fecha': '05/03/21',
    'paciente': 'Mariana Vega',
    'medico': 'Ulises Perez',
    'consultario': 13
    },
    {
    'fecha': '06/03/21',
    'paciente': 'Martha Tellez',
    'medico': 'Oscar Fernández',
    'consultario': 18
    }
]
print(cita[1]['paciente'])
cita[1]['paciente'] = 'Oscar Rico'
print(cita[1]['paciente'])
# Out:
# Mariana Vega
# Oscar Rico

# %% [markdown]
# #**Objetos web Json**
#
#
# ```
# [
#   {
#     "faceId": "be14f796-bbdb-4e73-91e6-135bc796ac98",
#     "faceRectangle": {
#       "top": 76,
#       "left": 446,
#       "width": 226,
#       "height": 284
#     },
#     "faceAttributes": null,
#     "faceLandmarks": null
#   }
# ]
# ```

# %%
cognitive_response = [
  {
    "rectangle": {
      "x": 6,
      "y": 390,
      "w": 48,
      "h": 40
    },
    "object": "footwear",
    "confidence": 0.513
  },
  {
    "rectangle": {
      "x": 104,
      "y": 104,
      "w": 127,
      "h": 323
    },
    "object": "person",
    "confidence": 0.763
  },
  {
    "rectangle": {
      "x": 174,
      "y": 236,
      "w": 113,
      "h": 74
    },
    "object": "Laptop",
    "parent": {
      "object": "computer",
      "confidence": 0.56
    },
    "confidence": 0.553
  },
  {
    "rectangle": {
      "x": 351,
      "y": 331,
      "w": 154,
      "h": 99
    },
    "object": "seating",
    "confidence": 0.525
  },
  {
    "rectangle": {
      "x": 0,
      "y": 101,
      "w": 174,
      "h": 329
    },
    "object": "person",
    "confidence": 0.855
  },
  {
    "rectangle": {
      "x": 223,
      "y": 99,
      "w": 199,
      "h": 322
    },
    "object": "person",
    "confidence": 0.725
  },
  {
    "rectangle": {
      "x": 154,
      "y": 191,
      "w": 387,
      "h": 218
    },
    "object": "seating",
    "confidence": 0.679
  },
  {
    "rectangle": {
      "x": 111,
      "y": 275,
      "w": 264,
      "h": 151
    },
    "object": "table",
    "confidence": 0.601
  }
]

# %%
for indice in range(len(cognitive_response)): # len - legth (# elementos)
    print(cognitive_response[indice]["object"])
# Out:
# footwear
# person
# Laptop
# seating
# person
# person
# seating
# table

# %%
for indice in range(len(cognitive_response)): # len - legth (# elementos)
    x = cognitive_response[indice]["rectangle"]["x"]
    y = cognitive_response[indice]["rectangle"]["y"]
    print((x, y))
# Out:
# (6, 390)
# (104, 104)
# (174, 236)
# (351, 331)
# (0, 101)
# (223, 99)
# (154, 191)
# (111, 275)

# %% [markdown]
# #**INTRO a request**
#
#
# ```
# import requests
#
#
# url = "https://pokeapi.co/api/v2/pokemon/144"
# response = requests.get(url)
#
# print(response.json())
# ```
# Al formatear la respuesta, dberíamos obtener un objeto JSON como el que sigue:
#
#
# ```
# {
#   "abilities": [
#     {
#       "ability": {
#         "name": "pressure",
#         "url": "https://pokeapi.co/api/v2/ability/46/"
#       },
#       "is_hidden": false,
#       "slot": 1
#     },
#     {
#       "ability": {
#         "name": "snow-cloak",
#         "url": "https://pokeapi.co/api/v2/ability/81/"
#       },
#       "is_hidden": true,
#       "slot": 3
#     }
#   ],
#   "base_experience": 261,
#   "forms": [
#     {
#       "name": "articuno",
#       "url": "https://pokeapi.co/api/v2/pokemon-form/144/"
#     }
#   ],
#
#   ...
#
#   "types": [
#     {
#       "slot": 1,
#       "type": {
#         "name": "ice",
#         "url": "https://pokeapi.co/api/v2/type/15/"
#       }
#     },
#     {
#       "slot": 2,
#       "type": {
#         "name": "flying",
#         "url": "https://pokeapi.co/api/v2/type/3/"
#       }
#     }
#   ],
#   "weight": 554
# }
# ```

# %%
import requests
from pprint import pprint 

url = "https://pokeapi.co/api/v2/pokemon/25"
r = requests.get(url)
print(r.json())
pprint(r.json())
# Out:
# {'abilities': [{'ability': {'name': 'static', 'url': 'https://pokeapi.co/api/v2/ability/9/'}, 'is_hidden': False, 'slot': 1}, {'ability': {'name': 'lightning-rod', 'url': 'https://pokeapi.co/api/v2/ability/31/'}, 'is_hidden': True, 'slot': 3}], 'base_experience': 112, 'forms': [{'name': 'pikachu', 'url': 'https://pokeapi.co/api/v2/pokemon-form/25/'}], 'game_indices': [{'game_index': 84, 'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}}, {'game_index': 84, 'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}}, {'game_index': 84, 'version': {'name': 'yellow', 'url': 'https://pokeapi.co/api/v2/version/3/'}}, {'game_index': 25, 'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}}, {'game_index': 25, 'version': {'name': 'silver', 'url': 'https://pokeapi.co/api/v2/version/5/'}}, {'game_index': 25, 'version': {'name': 'crystal', 'url': 'https://pokeapi.co/api/v2/version/6/'}}, {'game_index': 25, 'version': {'name': 'ruby'
# ...
